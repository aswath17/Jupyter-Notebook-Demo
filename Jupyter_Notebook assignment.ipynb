# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aswathaman Chandrapandiyan** <br>
# I just graduated from B.E copmuter science And I want to be a Data scientist

# %% [markdown]
# _I came across Data science when I worked for my final year project for my undergraduate program. I wanted to learn more start my career as a Data scientist when I dig about it through some youtubers._

# %% [markdown]
# ### Print the addition of Two Numbers (a & b) strore in C and display C ##

# %%
a=10
b=17
c=a+b
print(c)
# Out:
# 27

# %% [markdown]
# * I
# * We
# * You
# <table>
#   <tr>
#     <th>S.no</th>
#     <th>Name</th>
#     <th>Country</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Jim</td>
#     <td>Germany</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Dwight</td>
#     <td>Mexico</td>
#   </tr>
# </table>
# <a href="https://youtu.be/o_nxIQTM_B0"> A Hyperlink</a>
#
# <ol>
#     <li>Office</li>
#     <li>HIMYM</li>
#     <li>Modern Family</li>
# </ol>
